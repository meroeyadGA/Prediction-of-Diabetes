# %% [markdown]
# # Capstone: Prediction of Diabetes Using Data Mining Techniques
#
# *Prepared by:
# Meroe Yadollahi
# GA-DSI-CC9*
#
# ## *Technical Report*
#
#
# ### Abstract
#
# My motivation in this project is to find out why the Pima Indians and other non-whites get diabetes so often and therefore identify those who are likely to become diabetic. Finding out the cause of diabetes could prevent the prevalence of diabetes in new generations of Pima Indians.
#
# Diabetes is a metabolic disease that can be identified by high blood glucose level, which is a consequence of insulin starvation of the body. It may be that body does not produce enough insulin, or may be its resistance to the effect of insulin that causes the increase in the blood glucose level. Data mining methods, especially classification models can be used to help physicians to improve their prognosis and diagnosis procedures. There has been a lot of effort in the past few decades on improving the performance and accuracy of different classification method aimed at identifying diabetes.
#
#
#
# ### Who is Pima Indians ?
#
# "The Pima (or Akimel O'odham, also spelled Akimel O'otham, "River People", formerly known as Pima) are a group of Native Americans living in an area consisting of what is now central and southern Arizona. The majority population of the surviving two bands of the Akimel O'odham are based in two reservations: the Keli Akimel O'otham on the Gila River Indian Community (GRIC) and the On'k Akimel O'odham on the Salt River Pima-Maricopa Indian Community (SRPMIC)." Wikipedia
#
#
#
# ### 1. Introduction
#
#
# Diabetes is known as a metabolic chronic disease that affects between 2 to 4 percent of the global human population. Hence from a public health and health economics perspective, it is critical to be able to effectively diagnose and treat diabetic patients. Diabetes is mostly characterized by high blood glucose level, which is a result of insulin starvation in the body (either body does not produce enough insulin or resists against the effect of insulin). Insulin is a critical substance in the body that is used in the process of turning sugar, fat and protein into energy. It is also known that presence of diabetes increases the risk of heart and kidney disease, blood pressure and nerve damage.
# In the past few decades and with the rapid increase in the data storage and computation capability of modern computers, there has been a lot of interest in using data mining techniques in the medical domain to explore patient’s data and extract predictive models. These models help physicians in the prognosis, diagnosis and treatment procedures. One of the popular and effective methods for building classification models is based on decision trees. In this method a set of binary rules are used in order to calculate a target value.
# In this project, I will use data mining technique to classify diabetic and non-diabetic patients. Empirical results of Pima Indian diabetes data classification show that decision tree technique outperform other standard data mining techniques for diabetes classification. Hence, I will mainly focus on decision tree as our primary classifier and evaluate its performance in terms of classification accuracy and ROC curves. I also compare the results with K-Nearest Neighbor (KNN) technique and Logistic Regression and Support Vector Machine techniques. However, in this project we will infer that KNN model is showing better results than Decision Tree.
#
#
#
# ### 2. Data
#
# ### 2.1  Description
#
# The data set that I used is “Pima Indians Diabetes” from Kaggle. The data source uses 768 samples with two class problems to test whether the patient would test positive or negative for diabetes. There are 268 individual of class value ‘1’ being interpreted as “tested positive for diabetes” and 500 individual of class value ‘0’. All the patients in this database are Pima Indian women at least 21 years old. The objective of this project is to decide whether an individual was diagnosed as diabetes positive or negative by considering some personal data, such as number of times pregnant, age, and some result of medical examinations, like body mass index, blood pressure, result of glucose tolerance test, etc.
#
# In this data set there are 8 numeric attributes, and 1 binary response variable; The attributes are given below:
#
# 1) Number of times pregnant
# 2) Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3) Diastolic blood pressure (mm Hg)
# 4) Triceps skin fold thickness (mm)
# 5) 2-hour serum insulin (mu U/ml)
# 6) Body mass index (weight in kg/(height in m)^2)
# 7) Diabetes pedigree function
# 8) Age (years)
# 9) Diabetic (No=0 or Yes=1)
#
#
# ### 2.2  Summary Statistics:
#
# Table 1 and Table 2 provide a sample and a summary statistics of the data to see how our data looks like. Beside looking at some statistical information about our variables I also need to look at these variables side by side to see whether they have some relationships with each other or not and how they can have impact on the testing result being positive or negative for diabetes.
#
#
# ![Table 1: Sample Pima Indians Diabetes data set](attachment:Screen%20Shot%202019-12-02%20at%2011.19.27%20PM.png)
#
#
# ![Table 3: Summary Statistics](attachment:Screen%20Shot%202019-12-02%20at%2011.31.42%20PM.png)
#
#
#
# Table 3 represents a color-coded correlation matrix. The highlighted numbers are the areas of highest correlation. Variables such as Age and Number of times pregnant with significant relationships are valuable attributes that can help us to classify our model.
#
# ![Screen%20Shot%202019-12-05%20at%201.02.22%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%201.02.22%20PM.png)
#
#
# ### 2.3    Visualization
#
# Next step is to visualize our data. I have prepared the Histogram plot, Box plot and Scatter plot of our data to get into more details.
#
#
# #### Histogram Plots of all attributes:
#
# A histogram is a graphical representation of the distribution of numerical data. It is an estimate of the probability distribution of a continuous variable.
#
# ![Screen%20Shot%202019-12-02%20at%2011.28.54%20PM.png](attachment:Screen%20Shot%202019-12-02%20at%2011.28.54%20PM.png)
#
# Now to see the relationship each predictive variable has to the response variable of diabetic we need to look at the Box plots and the Scatter plots in Figure 2, 3 and 4.
# A boxplot is a graphical representation of statistical measures like median, upper and lower quartiles, minimum and maximum data values. These box plots tell a story of which predictive variables are going to be most useful when using data mining techniques.
#
# From Figure 2 we can see that he variables that have a significant difference in medians of their response variables are Number of times pregnant and Plasma glucose concentration and Age. But we also have to see how the plots look like if we also add the data points into them.
#
# ![Screen%20Shot%202019-12-02%20at%2011.28.54%20PM.png](./images/boxplot.png)
#
# From the Figure 3 shown below we can also add the body mass index to one of the variables that can have significant impact to the diabetes test result.
#
# ![pairplot.png](attachment:pairplot.png)
#
# Therefore we can conclude that by looking at the box plots and scatter plots for each attribute in Figure 2 and 3 we can say that there are significant differences between the levels of response variable in: Number of Times Pregnant and Plasma Glucose Concentration and Body Mass Index and Age.
#
# ### 3.  Data Mining Teqnique
#
# I have used several data mining techniques such as Classification Tree (Decision Tree), Support Vector Machine (SVM), and K- nearest neighbor (K-NN), Random Forest Classifier to classify my data and now I’m going to explain one by one in sections bellow.
#
#
# ### 3.1 Decision Tree
#
# Decision tree is one of the popular and important classifier, which is easy and simple to implement. It handle huge amount of dimensional data. It is more suitable for exploratory knowledge discovery. The results attained from Decision Tree are easier to interpret and read.
#
# ![Screen%20Shot%202019-12-05%20at%2012.24.53%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%2012.24.53%20PM.png)
#
# - true positives (TP): These are cases in which we correctly predicted diabetes as result.
# - true negatives (TN): We correctly predicted no diabetes and they don't have the disease.
# - false positives (FP): We correctly predicted no diabetes, but they actually had the disease. (Also known as a "Type I error.")
# - false negatives (FN): We correctly predicted diabetes, but they actually had no disease. (Also known as a "Type II error.")
#
#
# ![Screen%20Shot%202019-12-05%20at%2012.20.49%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%2012.20.49%20PM.png)
#
# #### Precision :
# Precision is the ratio of correctly predicted positive observations to the total predicted positive observations.
#
# #### Recall (Sensitivity) :
# Recall is the ratio of correctly predicted positive observations to the all observations in actual class
#
# #### F1 score :
# F1 Score is the weighted average of Precision and Recall. Therefore, this score takes both false positives and false negatives into account
#
# ![Screen%20Shot%202019-12-05%20at%2012.42.26%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%2012.42.26%20PM.png)
#
#
#
# ### 3.1.2 Applying GridSearch and the Classification Report for Decision Tree:
#
# To find the best tree we used GridSearch.
#
# Hyperparameters of Decision Trees:
# - The maximum depth of the tree: 'max_depth': 3
# - The minimum number of samples required to split an internal node : 'min_samples_leaf': 3
# - The minimum number of samples required to be in a leaf node (a terminal node at the end of the tree): 'min_samples_split': 15
#
# Report which includes Precision, Recall and F1-Score.
#
# ![Screen%20Shot%202019-12-05%20at%205.43.29%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%205.43.29%20PM.png)
#
#
#
#
# ### 3.1.3 ROC - AUC for Decision Tree
#
# ▪ The red line depicts Decision Tree curve area which is 0.89.
# ▪ The dashed line in the diagonal represents the ROC curve of a random predictor. The random predictor is commonly used as a baseline to see whether the model is useful or not.
#
# ![Screen%20Shot%202019-12-05%20at%205.35.47%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%205.35.47%20PM.png)
#
# #### Evaluation:
#
# The graph is called a Receiver Operating Characteristic curve (or ROC curve.) It is a plot of the true positive rate against the false positive rate for the different points.
# ▪ It shows the tradeoff between True Positive Rate (TPR) and False Positive Rate (FPR) (any increase in (TPR) will be accompanied by a decrease in (FPR)).
# ▪ The closer the curve towards TPR of the ROC space, the more accurate the test.
# ▪ The closer the curve towards the FPR of the ROC space, the less accurate the test.
# ▪ The Area Under the Curve (AUC) is a measure to determine the model effectiveness. The more AUC for a model comes to 1, the better it is. So models with higher AUCs are preferred over those with lower AUCs.
#
#
# ### 3.2  K_Nearest Neighbors
#
# In pattern recognition, the k-nearest neighbors algorithm is a non-parametric method used for classification and regression. In both cases, the input consists of the k closest training examples in the feature space. The output depends on whether k-NN is used for classification or regression:
#
#
# - In k-NN classification, the output is a class membership. An object is classified by a plurality vote of its neighbors, with the object being assigned to the class most common among its k nearest neighbors (k is a positive integer, typically small). If k = 1, then the object is simply assigned to the class of that single nearest neighbor.
#
# - In k-NN regression, the output is the property value for the object. This value is the average of the values of k nearest neighbors.
#
#
# The score that comes from testing on the same datapoints that were used for training:
# Max train score 100.0 % and k = [1]
#
# The score that comes from testing on the datapoints that were split in the beginning to be used for testing solely:
# Max test score 86.45 % and k = [3]
#
#
# ![Screen%20Shot%202019-12-05%20at%201.25.34%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%201.25.34%20PM.png)
#
# ### 3.2.1 Result Visualization for K_Nearest Neighbors
#
# ![Screen%20Shot%202019-12-05%20at%201.24.14%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%201.24.14%20PM.png)
#
#
# ### 3.2.2 Confusion Matrix for the K_Nearest Neighbors:
#
# ![Screen%20Shot%202019-12-05%20at%201.27.23%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%201.27.23%20PM.png)
#
# ### 3.2.3 Classification Report for K_Nearest Neighbors:
#
# ![Screen%20Shot%202019-12-05%20at%201.28.10%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%201.28.10%20PM.png)
#
#
# ## 4.  Alternate Model Comparison (K_Nearest Neighbors and Decision Tree):
#
# ![Screen%20Shot%202019-12-05%20at%201.31.36%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%201.31.36%20PM.png)
#  The Area Under Curve(AUC) for KNN is 0.87.
#
# ![Screen%20Shot%202019-12-05%20at%205.35.47%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%205.35.47%20PM.png)
# The Area Under Curve(AUC) for Decision Tree is 0.89.
#
#
# ![Screen%20Shot%202019-12-05%20at%206.06.56%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%206.06.56%20PM.png)
#
# So by comparing both the results we infer that K_Nearest Neighbor Model is showing better results in comparison to Decision Tree Model.
#
#
# ## 5. Feature Extraction/ Selection:
#
# 1) A lot many features can affect the accuracy of the algorithm.
#
# 2) Feature Extraction means to select only the important features in-order to improve the accuracy of the algorithm.
#
# 3) It reduces training time and reduces overfitting
#
# 4) We can choose important features in 2 ways:
#
#    a) Correlation matrix--> selecting only the uncorrelated features.
#
#    b) RandomForestClassifier--> It gives the importance of the features
#
#
#
# ## 5.1 Correlation Matrix
#
# ![Screen%20Shot%202019-12-05%20at%206.12.07%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%206.12.07%20PM.png)
#
# #### Observations:
# All the features look to be uncorrelated. So we cannot eliminate any features just by looking at the correlation matrix.
#
#
# ## 5.2 Random Forest Classifier
#
# ![Screen%20Shot%202019-12-05%20at%207.00.00%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%207.00.00%20PM.png)
#
#
# #### Observations:
# The important features are: Insulin, Glucose, SkinThickness, Age, BMI
#
#
#
# ## 5.3 Using Only Important Features And Standardisation
#
# ![Screen%20Shot%202019-12-05%20at%207.03.51%20PM.png](attachment:Screen%20Shot%202019-12-05%20at%207.03.51%20PM.png)
#
#
# The above dataframe shows the new accuracy of the models after feature selection. We can see that the Accuarcy for Radial Svm increases by 17% and for Logistic Regression and Decision Tree the Accuracy increases 6% and 3%. For KNN the accuracy decreases by 6%.
#
#
# ## 6. Conclusion
#
# In this project, we studied classifying diabetic and non-diabetic patients. We used the Histogram Plot, Box Plot, and Scatter Plot to see which one is more informative for our classification task. Our experimental results of Pima Indian diabetes data classification show that the K_Nearest Neighbor technique outperforms other standard data mining techniques such as Decision Tree and Logistic Regression and Support Vectore Machin. We evaluated the performance of
# different methods in terms of classification accuracy and ROC curves.
